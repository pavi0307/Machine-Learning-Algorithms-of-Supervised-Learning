# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
loan_data=pd.read_csv(r"D:\Downloads of csv\Loan.csv")
loan_data.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  \
# 0         Master          22       13152            48       Married
# 1      Associate          15       26045            48        Single
# 2       Bachelor          26       17627            36       Married
# 3    High School          34       37898            96        Single
# 4      Associate          17        9184            36       Married
#
#    NumberOfDependents HomeOwnershipStatus  MonthlyDebtPayments  \
# 0                   2                 Own                  183
# ...

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  object
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %%
loan_data.describe()
# Out:
#                 Age   AnnualIncome   CreditScore    Experience     LoanAmount  \
# count  20000.000000   20000.000000  20000.000000  20000.000000   20000.000000
# mean      39.752600   59161.473550    571.612400     17.522750   24882.867800
# std       11.622713   40350.845168     50.997358     11.316836   13427.421217
# min       18.000000   15000.000000    343.000000      0.000000    3674.000000
# 25%       32.000000   31679.000000    540.000000      9.000000   15575.000000
# 50%       40.000000   48566.000000    578.000000     17.000000   21914.500000
# 75%       48.000000   74391.000000    609.000000     25.000000   30835.000000
# max       80.000000  485341.000000    712.000000     61.000000  184732.000000
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count  20000.000000        20000.000000         20000.000000
# mean      54.057000            1.517300           454.292700
# std       24.664857            1.386325           240.507609
# ...

# %%
object_col=loan_data.select_dtypes(include=['object'])

# %%
loan_data.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  \
# 0         Master          22       13152            48       Married
# 1      Associate          15       26045            48        Single
# 2       Bachelor          26       17627            36       Married
# 3    High School          34       37898            96        Single
# 4      Associate          17        9184            36       Married
#
#    NumberOfDependents HomeOwnershipStatus  MonthlyDebtPayments  \
# 0                   2                 Own                  183
# ...

# %%
print(object_col.head())
# Out:
#   ApplicationDate EmploymentStatus EducationLevel MaritalStatus  \
# 0      2018-01-01         Employed         Master       Married
# 1      2018-01-02         Employed      Associate        Single
# 2      2018-01-03         Employed       Bachelor       Married
# 3      2018-01-04         Employed    High School        Single
# 4      2018-01-05         Employed      Associate       Married
#
#   HomeOwnershipStatus         LoanPurpose
# 0                 Own                Home
# 1            Mortgage  Debt Consolidation
# 2                Rent           Education
# 3            Mortgage                Home
# 4            Mortgage  Debt Consolidation

# %%
emp=pd.get_dummies(loan_data['EmploymentStatus'],prefix='EmploymentStatus',drop_first=True,dtype='int64')
loan_data=pd.concat([loan_data,emp],axis=1)
edu=pd.get_dummies(loan_data['EducationLevel'],prefix='EducationLevel',drop_first=True,dtype='int64')
loan_data=pd.concat([loan_data,edu],axis=1)
mar=pd.get_dummies(loan_data['MaritalStatus'],prefix='MaritalStatus',drop_first=True,dtype='int64')
loan_data=pd.concat([loan_data,mar],axis=1)
home=pd.get_dummies(loan_data['HomeOwnershipStatus'],prefix='HomeOwnershipStatus',drop_first=True,dtype='int64')
loan_data=pd.concat([loan_data,home],axis=1)
loanp=pd.get_dummies(loan_data['LoanPurpose'],prefix='LoanPurpose',drop_first=True,dtype='int64')
loan_data=pd.concat([loan_data,loanp],axis=1)

# %%
loan_data.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  \
# 0         Master          22       13152            48       Married
# 1      Associate          15       26045            48        Single
# 2       Bachelor          26       17627            36       Married
# 3    High School          34       37898            96        Single
# 4      Associate          17        9184            36       Married
#
#    NumberOfDependents HomeOwnershipStatus  MonthlyDebtPayments  \
# 0                   2                 Own                  183
# ...

# %%
object_col.head()
# Out:
#   ApplicationDate EmploymentStatus EducationLevel MaritalStatus  \
# 0      2018-01-01         Employed         Master       Married
# 1      2018-01-02         Employed      Associate        Single
# 2      2018-01-03         Employed       Bachelor       Married
# 3      2018-01-04         Employed    High School        Single
# 4      2018-01-05         Employed      Associate       Married
#
#   HomeOwnershipStatus         LoanPurpose
# 0                 Own                Home
# 1            Mortgage  Debt Consolidation
# 2                Rent           Education
# 3            Mortgage                Home
# 4            Mortgage  Debt Consolidation

# %%
loan_data=loan_data.drop(columns=['ApplicationDate','EmploymentStatus','EducationLevel','MaritalStatus','HomeOwnershipStatus','LoanPurpose'],axis=1)

# %%
loan_data.head()
# Out:
#    Age  AnnualIncome  CreditScore  Experience  LoanAmount  LoanDuration  \
# 0   45         39948          617          22       13152            48
# 1   38         39709          628          15       26045            48
# 2   47         40724          570          26       17627            36
# 3   58         69084          545          34       37898            96
# 4   37        103264          594          17        9184            36
#
#    NumberOfDependents  MonthlyDebtPayments  CreditCardUtilizationRate  \
# 0                   2                  183                   0.354418
# 1                   1                  496                   0.087827
# 2                   2                  902                   0.137414
# 3                   1                  755                   0.267587
# 4                   1                  274                   0.320535
#
#    NumberOfOpenCreditLines  NumberOfCreditInquiries  DebtToIncomeRatio  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
loan_data['Age']=scaler.fit_transform(loan_data[['Age']])
loan_data['AnnualIncome']=scaler.fit_transform(loan_data[['AnnualIncome']])
loan_data['CreditScore']=scaler.fit_transform(loan_data[['CreditScore']])
loan_data['Experience']=scaler.fit_transform(loan_data[['Experience']])
loan_data['LoanAmount']=scaler.fit_transform(loan_data[['LoanAmount']])
loan_data['LoanDuration']=scaler.fit_transform(loan_data[['LoanDuration']])
loan_data['NumberOfDependents']=scaler.fit_transform(loan_data[['NumberOfDependents']])
loan_data['MonthlyDebtPayments']=scaler.fit_transform(loan_data[['MonthlyDebtPayments']])
loan_data['CreditCardUtilizationRate']=scaler.fit_transform(loan_data[['CreditCardUtilizationRate']])
loan_data['NumberOfOpenCreditLines']=scaler.fit_transform(loan_data[['NumberOfOpenCreditLines']])
loan_data['NumberOfCreditInquiries']=scaler.fit_transform(loan_data[['NumberOfCreditInquiries']])
loan_data['DebtToIncomeRatio']=scaler.fit_transform(loan_data[['DebtToIncomeRatio']])
loan_data['PaymentHistory']=scaler.fit_transform(loan_data[['PaymentHistory']])
loan_data['LengthOfCreditHistory']=scaler.fit_transform(loan_data[['LengthOfCreditHistory']])
loan_data['SavingsAccountBalance']=scaler.fit_transform(loan_data[['SavingsAccountBalance']])
loan_data['CheckingAccountBalance']=scaler.fit_transform(loan_data[['CheckingAccountBalance']])
loan_data['TotalAssets']=scaler.fit_transform(loan_data[['TotalAssets']])
loan_data['TotalLiabilities']=scaler.fit_transform(loan_data[['TotalLiabilities']])
loan_data['MonthlyIncome']=scaler.fit_transform(loan_data[['MonthlyIncome']])
loan_data['UtilityBillsPaymentHistory']=scaler.fit_transform(loan_data[['UtilityBillsPaymentHistory']])
loan_data['JobTenure']=scaler.fit_transform(loan_data[['JobTenure']])
loan_data['NetWorth']=scaler.fit_transform(loan_data[['NetWorth']])
loan_data['BaseInterestRate']=scaler.fit_transform(loan_data[['BaseInterestRate']])
loan_data['InterestRate']=scaler.fit_transform(loan_data[['InterestRate']])
loan_data['MonthlyLoanPayment']=scaler.fit_transform(loan_data[['MonthlyLoanPayment']])
loan_data['TotalDebtToIncomeRatio']=scaler.fit_transform(loan_data[['TotalDebtToIncomeRatio']])
loan_data['RiskScore']=scaler.fit_transform(loan_data[['RiskScore']])

# %%
loan_data.head()
# Out:
#         Age  AnnualIncome  CreditScore  Experience  LoanAmount  LoanDuration  \
# 0  0.435484      0.053042     0.742547    0.360656    0.052348      0.333333
# 1  0.322581      0.052534     0.772358    0.245902    0.123557      0.333333
# 2  0.467742      0.054692     0.615176    0.426230    0.077064      0.222222
# 3  0.645161      0.114989     0.547425    0.557377    0.189022      0.777778
# 4  0.306452      0.187660     0.680217    0.278689    0.030432      0.222222
#
#    NumberOfDependents  MonthlyDebtPayments  CreditCardUtilizationRate  \
# 0                 0.4             0.046358                   0.385684
# 1                 0.2             0.155455                   0.094775
# 2                 0.4             0.296968                   0.148886
# 3                 0.2             0.245730                   0.290933
# 4                 0.2             0.078076                   0.348711
#
#    NumberOfOpenCreditLines  NumberOfCreditInquiries  DebtToIncomeRatio  \
# ...

# %%
Q1=loan_data['RiskScore'].quantile(0.25)
Q3=loan_data['RiskScore'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['RiskScore']=loan_data['RiskScore'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound 0.039855072463768126 0.7644927536231885

# %%
Q1=loan_data['TotalDebtToIncomeRatio'].quantile(0.25)
Q3=loan_data['TotalDebtToIncomeRatio'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['TotalDebtToIncomeRatio']=loan_data['TotalDebtToIncomeRatio'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.0713856740776653 0.21319810674123293

# %%
Q1=loan_data['MonthlyLoanPayment'].quantile(0.25)
Q3=loan_data['MonthlyLoanPayment'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['MonthlyLoanPayment']=loan_data['MonthlyLoanPayment'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.04925869002137382 0.18009663888434796

# %%
Q1=loan_data['InterestRate'].quantile(0.25)
Q3=loan_data['InterestRate'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['InterestRate']=loan_data['InterestRate'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound 0.033732187741421504 0.7101109625370281

# %%
Q1=loan_data['BaseInterestRate'].quantile(0.25)
Q3=loan_data['BaseInterestRate'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['BaseInterestRate']=loan_data['BaseInterestRate'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound 0.04481991648722583 0.7380050413199093

# %%
Q1=loan_data['NetWorth'].quantile(0.25)
Q3=loan_data['NetWorth'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['NetWorth']=loan_data['NetWorth'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.04319461588005263 0.07991737209323774

# %%
Q1=loan_data['JobTenure'].quantile(0.25)
Q3=loan_data['JobTenure'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['JobTenure']=loan_data['JobTenure'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.09375 0.65625

# %%
Q1=loan_data['UtilityBillsPaymentHistory'].quantile(0.25)
Q3=loan_data['UtilityBillsPaymentHistory'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['UtilityBillsPaymentHistory']=loan_data['UtilityBillsPaymentHistory'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound 0.29821210613509264 1.1895785247941784

# %%
Q1=loan_data['MonthlyIncome'].quantile(0.25)
Q3=loan_data['MonthlyIncome'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['MonthlyIncome']=loan_data['MonthlyIncome'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.1650754385964913 0.43002631578947376

# %%
Q1=loan_data['TotalLiabilities'].quantile(0.25)
Q3=loan_data['TotalLiabilities'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['TotalLiabilities']=loan_data['TotalLiabilities'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.026183280049120287 0.0640110132469494

# %%
Q1=loan_data['TotalAssets'].quantile(0.25)
Q3=loan_data['TotalAssets'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['TotalAssets']=loan_data['TotalAssets'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.038301485867014276 0.09346400746658394

# %%
Q1=loan_data['CheckingAccountBalance'].quantile(0.25)
Q3=loan_data['CheckingAccountBalance'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['CheckingAccountBalance']=loan_data['CheckingAccountBalance'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.03492996879043922 0.08496041714242217

# %%
Q1=loan_data['SavingsAccountBalance'].quantile(0.25)
Q3=loan_data['SavingsAccountBalance'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['SavingsAccountBalance']=loan_data['SavingsAccountBalance'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.02514048876089913 0.06148258139348853

# %%
Q1=loan_data['LengthOfCreditHistory'].quantile(0.25)
Q3=loan_data['LengthOfCreditHistory'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['LengthOfCreditHistory']=loan_data['LengthOfCreditHistory'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.5 1.5

# %%
Q1=loan_data['PaymentHistory'].quantile(0.25)
Q3=loan_data['PaymentHistory'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['PaymentHistory']=loan_data['PaymentHistory'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound 0.10810810810810789 0.756756756756757

# %%
Q1=loan_data['DebtToIncomeRatio'].quantile(0.25)
Q3=loan_data['DebtToIncomeRatio'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['DebtToIncomeRatio']=loan_data['DebtToIncomeRatio'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.20501613234361044 0.8134577534464387

# %%
Q1=loan_data['NumberOfCreditInquiries'].quantile(0.25)
Q3=loan_data['NumberOfCreditInquiries'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['NumberOfCreditInquiries']=loan_data['NumberOfCreditInquiries'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.42857142857142855 0.7142857142857142

# %%
Q1=loan_data['NumberOfOpenCreditLines'].quantile(0.25)
Q3=loan_data['NumberOfOpenCreditLines'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['NumberOfOpenCreditLines']=loan_data['NumberOfOpenCreditLines'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.07692307692307693 0.5384615384615385

# %%
Q1=loan_data['CreditCardUtilizationRate'].quantile(0.25)
Q3=loan_data['CreditCardUtilizationRate'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['CreditCardUtilizationRate']=loan_data['CreditCardUtilizationRate'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.2018117541617881 0.8014135578494996

# %%
Q1=loan_data['MonthlyDebtPayments'].quantile(0.25)
Q3=loan_data['MonthlyDebtPayments'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['MonthlyDebtPayments']=loan_data['MonthlyDebtPayments'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.06308818403624959 0.3245033112582782

# %%
Q1=loan_data['NumberOfDependents'].quantile(0.25)
Q3=loan_data['NumberOfDependents'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['NumberOfDependents']=loan_data['NumberOfDependents'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.6000000000000001 1.0

# %%
Q1=loan_data['LoanDuration'].quantile(0.25)
Q3=loan_data['LoanDuration'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['LoanDuration']=loan_data['LoanDuration'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.2777777777777778 1.0555555555555556

# %%
Q1=loan_data['LoanAmount'].quantile(0.25)
Q3=loan_data['LoanAmount'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['LoanAmount']=loan_data['LoanAmount'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.06069325851384637 0.2764362800870439

# %%
Q1=loan_data['Experience'].quantile(0.25)
Q3=loan_data['Experience'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['Experience']=loan_data['Experience'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.2459016393442623 0.8032786885245902

# %%
Q1=loan_data['CreditScore'].quantile(0.25)
Q3=loan_data['CreditScore'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['CreditScore']=loan_data['CreditScore'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound 0.25338753387533874 1.0013550135501355

# %%
Q1=loan_data['AnnualIncome'].quantile(0.25)
Q3=loan_data['AnnualIncome'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['AnnualIncome']=loan_data['AnnualIncome'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.10075455892639598 0.26248827977998945

# %%
Q1=loan_data['Age'].quantile(0.25)
Q3=loan_data['Age'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Lower Bound Upper Bound",lower_bound,upper_bound)
loan_data['Age']=loan_data['Age'].apply(lambda x:lower_bound if x<lower_bound else(upper_bound if x>upper_bound else x))
# Out:
# Lower Bound Upper Bound -0.16129032258064513 0.8709677419354839

# %%
loan_data.corr()
# Out:
#                                      Age  AnnualIncome  CreditScore  \
# Age                             1.000000      0.151179     0.323970
# AnnualIncome                    0.151179      1.000000     0.114051
# CreditScore                     0.323970      0.114051     1.000000
# Experience                      0.982943      0.152571     0.328430
# LoanAmount                     -0.006143     -0.006941    -0.013251
# LoanDuration                   -0.006933      0.001316    -0.000572
# NumberOfDependents             -0.000556     -0.001762    -0.014588
# MonthlyDebtPayments             0.012436      0.003949     0.010023
# CreditCardUtilizationRate      -0.001586     -0.010733    -0.008874
# NumberOfOpenCreditLines        -0.001103     -0.012300    -0.008276
# NumberOfCreditInquiries        -0.001916     -0.004320    -0.001530
# DebtToIncomeRatio               0.004427      0.004141     0.002464
# BankruptcyHistory               0.010572      0.006093     0.009325
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
numeric_col=loan_data.select_dtypes(include=['float64','int64'])
X=sm.add_constant(numeric_col)
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i)for i in range(X.shape[1])]
print(vif_data.head(23))
# Out:
#                        feature          VIF
# 0                        const  2284.103744
# 1                          Age    29.619989
# 2                 AnnualIncome    93.220115
# 3                  CreditScore    45.462409
# 4                   Experience    29.750382
# 5                   LoanAmount    16.638690
# 6                 LoanDuration    31.026741
# 7           NumberOfDependents     1.002107
# 8          MonthlyDebtPayments     1.275103
# 9    CreditCardUtilizationRate     1.195633
# 10     NumberOfOpenCreditLines     1.002754
# 11     NumberOfCreditInquiries     1.001438
# 12           DebtToIncomeRatio     3.174664
# 13           BankruptcyHistory     3.397978
# 14        PreviousLoanDefaults     2.047011
# 15              PaymentHistory     1.004251
# 16       LengthOfCreditHistory     1.335260
# 17       SavingsAccountBalance     1.002197
# 18      CheckingAccountBalance     1.002063
# 19                 TotalAssets    18.448162
# ...

# %%
print(vif_data.tail(23))
# Out:
#                            feature        VIF
# 24                        NetWorth  20.789708
# 25                BaseInterestRate  87.324419
# 26                    InterestRate   3.579761
# 27              MonthlyLoanPayment   8.273267
# 28          TotalDebtToIncomeRatio   4.836704
# 29                    LoanApproved   9.326684
# 30                       RiskScore  21.301070
# 31  EmploymentStatus_Self-Employed   1.226334
# 32     EmploymentStatus_Unemployed   1.207463
# 33         EducationLevel_Bachelor   1.764227
# 34        EducationLevel_Doctorate   1.220341
# 35      EducationLevel_High School   1.755334
# 36           EducationLevel_Master   1.538988
# 37           MaritalStatus_Married   2.239700
# 38            MaritalStatus_Single   2.168716
# 39           MaritalStatus_Widowed   1.283588
# 40       HomeOwnershipStatus_Other   1.132249
# 41         HomeOwnershipStatus_Own   1.204090
# 42        HomeOwnershipStatus_Rent   1.234261
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
loan_data.head()
# Out:
#         Age  AnnualIncome  CreditScore  Experience  LoanAmount  LoanDuration  \
# 0  0.435484      0.053042     0.742547    0.360656    0.052348      0.333333
# 1  0.322581      0.052534     0.772358    0.245902    0.123557      0.333333
# 2  0.467742      0.054692     0.615176    0.426230    0.077064      0.222222
# 3  0.645161      0.114989     0.547425    0.557377    0.189022      0.777778
# 4  0.306452      0.187660     0.680217    0.278689    0.030432      0.222222
#
#    NumberOfDependents  MonthlyDebtPayments  CreditCardUtilizationRate  \
# 0                 0.4             0.046358                   0.385684
# 1                 0.2             0.155455                   0.094775
# 2                 0.4             0.296968                   0.148886
# 3                 0.2             0.245730                   0.290933
# 4                 0.2             0.078076                   0.348711
#
#    NumberOfOpenCreditLines  NumberOfCreditInquiries  DebtToIncomeRatio  \
# ...

# %%
x=loan_data.drop(['NumberOfDependents','NumberOfOpenCreditLines','NumberOfCreditInquiries','DebtToIncomeRatio','SavingsAccountBalance','CheckingAccountBalance','UtilityBillsPaymentHistory','JobTenure','MaritalStatus_Married','MaritalStatus_Single','MaritalStatus_Widowed','LoanPurpose_Debt Consolidation','LoanPurpose_Home','LoanApproved'],axis=1)
y=loan_data['LoanApproved']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Decision Tree Classifier
dt_model=DecisionTreeClassifier(criterion='entropy',max_depth=11,min_samples_split=16)
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=11, min_samples_split=16)

# %%
y_pred=dt_model.predict(x_test)

# %%
print("Classification Report:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2983
#            1       0.98      0.97      0.98      1017
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.99      0.99      0.99      4000
#
# Confusion Matrix:
#  [[2961   22]
#  [  26  991]]
# Accuracy Score:
#  0.988

# %%
params={"max_depth":[2,5,10],"criterion":['gini','entropy'],"max_features":[6,7,8],"min_samples_split":[11,13,14]}
tree=GridSearchCV(dt_model,scoring='accuracy',cv=5,param_grid=params,n_jobs=-1,verbose=0,return_train_score=True)

# %%
tree.fit(x_train,y_train)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5,
#              estimator=DecisionTreeClassifier(criterion='entropy', max_depth=11,
#                                               min_samples_split=16),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 5, 10], 'max_features': [6, 7, 8],
#                          'min_samples_split': [11, 13, 14]},
#              return_train_score=True, scoring='accuracy')

# %%
scores=tree.cv_results_

# %%
tree.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, max_features=8,
#                        min_samples_split=13)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
plt.plot(scores["param_max_depth"],scores["mean_train_score"],label="Training Accuracy")
plt.plot(scores["param_max_depth"],scores["mean_test_score"],label="Test Accuracy")
plt.legend()
plt.show()

# %%
train_error=1-scores["mean_train_score"]
test_error=1-scores["mean_test_score"]

# %%
plt.figure()
plt.plot(scores['param_max_depth'],train_error,label="Training Error",linestyle='--',color='orange')
plt.plot(scores['param_max_depth'],test_error,label="Testing Error",linestyle='--',color='green')
plt.grid()
plt.legend()
plt.show()

# %%
loan_data.head()
# Out:
#         Age  AnnualIncome  CreditScore  Experience  LoanAmount  LoanDuration  \
# 0  0.435484      0.053042     0.742547    0.360656    0.052348      0.333333
# 1  0.322581      0.052534     0.772358    0.245902    0.123557      0.333333
# 2  0.467742      0.054692     0.615176    0.426230    0.077064      0.222222
# 3  0.645161      0.114989     0.547425    0.557377    0.189022      0.777778
# 4  0.306452      0.187660     0.680217    0.278689    0.030432      0.222222
#
#    NumberOfDependents  MonthlyDebtPayments  CreditCardUtilizationRate  \
# 0                 0.4             0.046358                   0.385684
# 1                 0.2             0.155455                   0.094775
# 2                 0.4             0.296968                   0.148886
# 3                 0.2             0.245730                   0.290933
# 4                 0.2             0.078076                   0.348711
#
#    NumberOfOpenCreditLines  NumberOfCreditInquiries  DebtToIncomeRatio  \
# ...

# %%
x=loan_data.drop(['Age','AnnualIncome','CreditScore','Experience','LoanAmount','LoanDuration','TotalAssets','MonthlyIncome','NetWorth','BaseInterestRate','MonthlyLoanPayment','LoanApproved','NumberOfDependents','NumberOfOpenCreditLines','NumberOfCreditInquiries','DebtToIncomeRatio','SavingsAccountBalance','CheckingAccountBalance','UtilityBillsPaymentHistory','JobTenure','MaritalStatus_Married','MaritalStatus_Single','MaritalStatus_Widowed','LoanPurpose_Debt Consolidation','LoanPurpose_Home'],axis=1)
y=loan_data['LoanApproved']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
logistic_model=LogisticRegression()
logistic_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logistic_model.predict_proba(x_test)
y_pred_df=pd.DataFrame(y_pred)

# %%
y_pred_df.head()
# Out:
#           0         1
# 0  0.136271  0.863729
# 1  0.034067  0.965933
# 2  0.996373  0.003627
# 3  0.988358  0.011642
# 4  0.981885  0.018115

# %%
y_pred_1=y_pred_df.iloc[:,[1]]

# %%
y_test_df=pd.DataFrame(y_test)

# %%
y_test_df['PersonID']=y_test_df.index

# %%
y_pred_1.reset_index(drop=True,inplace=True)
y_test_df.reset_index(drop=True,inplace=True)

# %%
y_pred_final=pd.concat([y_pred_1,y_test_df],axis=1)

# %%
y_pred_final.head()
# Out:
#           1  LoanApproved  PersonID
# 0  0.863729             1     10650
# 1  0.965933             1      2041
# 2  0.003627             0      8668
# 3  0.011642             0      1114
# 4  0.018115             0     13902

# %%
y_pred_final=y_pred_final.rename(columns={1:"Loan_Approved_Prob"})

# %%
y_pred_final.head()
# Out:
#    Loan_Approved_Prob  LoanApproved  PersonID
# 0            0.863729             1     10650
# 1            0.965933             1      2041
# 2            0.003627             0      8668
# 3            0.011642             0      1114
# 4            0.018115             0     13902

# %%
y_pred_final['Predicted']=y_pred_final.Loan_Approved_Prob.map(lambda x: 1 if x>0.5 else 0)

# %%
y_pred_final.head()
# Out:
#    Loan_Approved_Prob  LoanApproved  PersonID  Predicted
# 0            0.863729             1     10650          1
# 1            0.965933             1      2041          1
# 2            0.003627             0      8668          0
# 3            0.011642             0      1114          0
# 4            0.018115             0     13902          0

# %%
print("Classification Report:\n",classification_report(y_pred_final.LoanApproved,y_pred_final.Predicted))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2983
#            1       0.98      0.96      0.97      1017
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.99      0.99      0.99      4000

# %%
confusion=confusion_matrix(y_pred_final.LoanApproved,y_pred_final.Predicted)
confusion
# Out:
# array([[2963,   20],
#        [  37,  980]])

# %%
print("Accuracy Score:\n",accuracy_score(y_pred_final.LoanApproved,y_pred_final.Predicted))
# Out:
# Accuracy Score:
#  0.98575

# %%
TP=confusion[1,1]
TN=confusion[0,0]
FP=confusion[0,1]
FN=confusion[1,0]

# %%
#Sesitivity or Recall 
TP/float(TP+FN)
# Out:
# np.float64(0.9636184857423795)

# %%
#Specificity True Negative
TN/float(TN+FP)
# Out:
# np.float64(0.9932953402614817)

# %%
#Precision or Positive Values
TP/float(TP+FP)
# Out:
# np.float64(0.98)

# %%
#Negative Values
TN/float(TN+FN)
# Out:
# np.float64(0.9876666666666667)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
def draw_roc(actual,probs):
    fpr,tpr,threshold=roc_curve(actual,probs,drop_intermediate=False)
    auc_curve=roc_auc_score(actual,probs)
    plt.figure()
    plt.plot(fpr,tpr,label='ROC Curve (area=%0.2f)' % auc_curve)
    plt.plot([0,1],[0,1],'k--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.0])
    plt.xlabel("False Positive Rate or (1-True Negative Rate)")
    plt.ylabel("Receiver Operating Characteristic Curve")
    plt.legend()
    plt.show()

# %%
draw_roc(y_pred_final.LoanApproved,y_pred_final.Predicted)

# %%
#KNN Classifier
x=loan_data.drop(['LoanApproved'],axis=1)
y=loan_data['LoanApproved']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
knn_model=KNeighborsClassifier(metric='minkowski',p=2,n_neighbors=20,n_jobs=-1)
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1, n_neighbors=20)

# %%
y_pred=knn_model.predict(x_test)

# %%
from sklearn.model_selection import cross_val_predict,cross_val_score

# %%
def print_score(clf,x_train,y_train,x_test,y_test,train=True):
    if train:
        print("Train Results:\n")
        print("Accuracy Score:{0:.4f}\n".format(accuracy_score(y_train,clf.predict(x_train))))
        print("Classification Report\n{}\n".format(classification_report(y_train,clf.predict(x_train))))
        print("Confusion Matrix:\n{}\n".format(confusion_matrix(y_train,clf.predict(x_train))))

        res=cross_val_score(clf,x_train,y_train,cv=11,scoring='accuracy')

    elif train==False:
        print("Test Results:\n")
        print("Accuracy Score:{0:.4f}\n".format(accuracy_score(y_test,clf.predict(x_test))))
        print("Classification Report:\n{}\n".format(classification_report(y_test,clf.predict(x_test))))
        print("confusion_matrix:\n{}\n".format(confusion_matrix(y_test,clf.predict(x_test))))

# %%
print_score(knn_model,x_train,y_train,x_test,y_test,train=True)
# Out:
# Train Results:
#
# Accuracy Score:0.8061
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89     10698
#            1       0.88      0.21      0.33      3302
#
#     accuracy                           0.81     14000
#    macro avg       0.84      0.60      0.61     14000
# weighted avg       0.82      0.81      0.76     14000
#
#
# Confusion Matrix:
# [[10604    94]
#  [ 2621   681]]

# %%
print_score(knn_model,x_train,y_train,x_test,y_test,train=False)
# Out:
# Test Results:
#
# Accuracy Score:0.7848
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.99      0.87      4522
#            1       0.81      0.17      0.27      1478
#
#     accuracy                           0.78      6000
#    macro avg       0.80      0.58      0.57      6000
# weighted avg       0.79      0.78      0.73      6000
#
#
# confusion_matrix:
# [[4465   57]
#  [1234  244]]

# %%
knn_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': -1,
#  'n_neighbors': 20,
#  'p': 2,
#  'weights': 'uniform'}

# %%
#Naive Bayes
x=loan_data.drop(['LoanApproved'],axis=1)
y=loan_data['LoanApproved']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
nb_model=GaussianNB()
nb_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb_model.predict(x_test)

# %%
def print_score(clf,x_train,y_train,x_test,y_test,train=True):
    if train:
        print("Train Results:\n")
        print("Accuracy Score:{0:.4f}\n".format(accuracy_score(y_train,clf.predict(x_train))))
        print("Classification Report:\n{}\n".format(classification_report(y_train,clf.predict(x_train))))
        print("Confusion Matrix:\n{}\n".format(confusion_matrix(y_train,clf.predict(x_train))))

        res=cross_val_score(clf,x_train,y_train,cv=21,scoring='accuracy')

    elif train==False:
        print("Test Result:\n")
        print("Accuracy Score:{0:.4f}\n".format(accuracy_score(y_test,clf.predict(x_test))))
        print("Classification Report:\n{}\n".format(classification_report(y_test,clf.predict(x_test))))
        print("Confusion Matrix:\n{}\n".format(confusion_matrix(y_test,clf.predict(x_test))))

# %%
print_score(nb_model,x_train,y_train,x_test,y_test,train=True)
# Out:
# Train Results:
#
# Accuracy Score:0.9538
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97     10698
#            1       0.87      0.95      0.91      3302
#
#     accuracy                           0.95     14000
#    macro avg       0.93      0.95      0.94     14000
# weighted avg       0.96      0.95      0.95     14000
#
#
# Confusion Matrix:
# [[10228   470]
#  [  177  3125]]

# %%
print_score(nb_model,x_train,y_train,x_test,y_test,train=False)
# Out:
# Test Result:
#
# Accuracy Score:0.9522
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97      4522
#            1       0.87      0.95      0.91      1478
#
#     accuracy                           0.95      6000
#    macro avg       0.93      0.95      0.94      6000
# weighted avg       0.96      0.95      0.95      6000
#
#
# Confusion Matrix:
# [[4303  219]
#  [  68 1410]]
